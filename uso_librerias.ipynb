# %% [markdown]
# <a href="https://colab.research.google.com/github/dannyRT21/Progra3-2025/blob/librerias/uso_librerias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotilb.pylot as plt
import seaborn as sns
